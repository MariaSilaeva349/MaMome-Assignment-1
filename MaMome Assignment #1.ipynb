# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("C:/Users/mrsil/OneDrive/Desktop/Iman Genius PIe chart-Revised.xlsx", sheet_name="Sept2020&June2021&Aug2021")

# %%
data.head()
# Out:
#                                               101520  Healthy.T2.004  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...        0.000193
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...        0.118155
# 4                                                NaN             NaN
#
#    Healthy.T2.010  Healthy.T3.014  Healthy.T3.015  Healthy.T3.017  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2        0.000185        0.000703        0.000000        0.000360
# 3        0.100600        0.011601        0.015725        0.046781
# 4             NaN             NaN             NaN             NaN
#
#    Healthy.T3.019  Healthy.T2.033  Unhealthy.T2.012  Unhealthy.T3.018  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 90 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   101520                              118 non-null    object
#  1   Healthy.T2.004                      118 non-null    float64
#  2   Healthy.T2.010                      118 non-null    float64
#  3   Healthy.T3.014                      118 non-null    float64
#  4   Healthy.T3.015                      118 non-null    float64
#  5   Healthy.T3.017                      118 non-null    float64
#  6   Healthy.T3.019                      118 non-null    float64
#  7   Healthy.T2.033                      118 non-null    float64
#  8   Unhealthy.T2.012                    118 non-null    float64
#  9   Unhealthy.T3.018                    118 non-null    float64
#  10  Unhealthy.T3.022                    118 non-null    float64
# ...

# %%
data['compare'] = (data[101520] == data[61421]) & (data[61421] == data[82321])

# %%
data.head()
# Out:
#                                               101520  Healthy.T2.004  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...        0.000193
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...        0.118155
# 4                                                NaN             NaN
#
#    Healthy.T2.010  Healthy.T3.014  Healthy.T3.015  Healthy.T3.017  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2        0.000185        0.000703        0.000000        0.000360
# 3        0.100600        0.011601        0.015725        0.046781
# 4             NaN             NaN             NaN             NaN
#
#    Healthy.T3.019  Healthy.T2.033  Unhealthy.T2.012  Unhealthy.T3.018  ...  \
# ...

# %%
# data['compare'] = data[101520] = data[61421] = data[82321]

# %%
columns=data[[101520,61421,82321,'compare']]

# %%
columns.head()
# Out:
#                                               101520  \
# 0                                                NaN
# 1                                                NaN
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...
# 4                                                NaN
#
#                                                61421  \
# 0  k__Archaea;p__Euryarchaeota;c__Methanobacteria...
# 1  k__Archaea;p__Euryarchaeota;c__Methanobacteria...
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...
# 4  k__Bacteria;p__Actinobacteria;c__Actinobacteri...
#
#                                                82321  compare
# 0  k__Archaea;p__Euryarchaeota;c__Methanobacteria...    False
# 1  k__Archaea;p__Euryarchaeota;c__Methanobacteria...    False
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...     True
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...     True
# ...
